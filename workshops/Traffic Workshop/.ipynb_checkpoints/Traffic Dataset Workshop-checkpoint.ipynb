# %% [markdown]
# # Traffic Collisions Dataset

# %% [markdown]
# ### Welcome to DS3's first datathon!

# %% [markdown]
# This is going to be a summary of the traffic collisions dataset, as well as an intro to Pandas, Matplotlib, and Sci-kit learn to give you some jumping off points of what you could do.
#
# This data is from the city of San Diego's open data portal, https://data.sandiego.gov/.  This is real data relating to San Diego traffic and collisions that you will be able to work with.
#
# Collisions: https://data.sandiego.gov/datasets/police-collisions/
#
# Traffic Volumes: https://data.sandiego.gov/datasets/traffic-volumes/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Data

# %%
collisions = pd.read_csv("pd_collisions_datasd.csv")
counts = pd.read_csv("traffic_counts_datasd.csv")

# %%
collisions.head(3)
# Out:
#   report_id            date_time  police_beat  street_no street_dir  \
# 0    170166  2017-01-01 00:01:00          124       8300
# 1    170101  2017-01-01 00:01:00          322       6400
# 2    170218  2017-01-01 00:01:00          325       8100
#
#    street_name street_type cross_st_dir cross_st_name cross_st_type  \
# 0  CAM DEL ORO
# 1     CRAWFORD      STREET
# 2  ROYAL GORGE       DRIVE
#
#   violation_section violation_type  \
# 0          MISC-HAZ             VC
# 1          MISC-HAZ             VC
# 2             22107             VC
#
#                                          charge_desc  injured  killed  \
# 0  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# 1  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# 2             TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
#
#    hit_run_lvl
# 0  MISDEMEANOR
# 1  MISDEMEANOR
# 2  MISDEMEANOR

# %%
counts.head(3)
# Out:
#            id street_name         limits all_count northbound_count  \
# 0  01AV018207       01 AV  A ST - ASH ST                      18010
# 1  01AV015210       01 AV  A ST - ASH ST                      20060
# 2  01AV018213       01 AV  A ST - ASH ST                      19597
#
#    southbound_count  eastbound_count  westbound_count  total_count  file_no  \
# 0               NaN              NaN              NaN        18010  0182-07
# 1               NaN              NaN              NaN        20060  0152-10
# 2               NaN              NaN              NaN        19597  0182-13
#
#             count_date
# 0  2007-03-13 00:00:00
# 1  2010-03-18 00:00:00
# 2  2013-03-12 00:00:00

# %% [markdown]
# ### What do the csvs include?

# %% [markdown]
# ## Pandas Tutorial

# %% [markdown]
# Let's see how we can use Pandas to clean, filter, and manipulate our data so that you can learn how to use it if you don't already, and maybe get some ideas on what you could do.

# %% [markdown]
# Before we can work on anything else, let's have a look at what data are included.
#
# #### Collisions
#
# The collisions dataset comes with information about when the collision occurred, what police beat the collision occurred in, street number, name, and type, violation section, type, and charge description.
#
# #### Volumes
#
# The volumes dataset contains info on the street name, number of cars going north, south, east, and west, the total count, and when the count of cars occurred.

# %% [markdown]
# ### Selecting data

# %%
collisions['street_name'].head()
# Out:
# 0    CAM DEL ORO
# 1       CRAWFORD
# 2    ROYAL GORGE
# 3        VALERIO
# 4           11TH
# Name: street_name, dtype: object

# %%
collisions[['report_id', 'street_name']].head()
# Out:
#   report_id  street_name
# 0    170166  CAM DEL ORO
# 1    170101     CRAWFORD
# 2    170218  ROYAL GORGE
# 3    170082      VALERIO
# 4    170097         11TH

# %%
collisions[collisions['injured'] > 1].head(3)
# Out:
#    report_id            date_time  police_beat  street_no street_dir  \
# 25    170257  2017-01-01 18:07:00          611       3700
# 27    170146  2017-01-01 19:45:00          822       5800
# 29    170122  2017-01-01 22:15:00          841       3400
#
#      street_name street_type cross_st_dir cross_st_name cross_st_type  \
# 25  SPORTS ARENA   BOULEVARD
# 27      EL CAJON   BOULEVARD
# 29       COLLEGE      AVENUE
#
#    violation_section violation_type  \
# 25             22107             VC
# 27            21801A             VC
# 29             21804             VC
#
#                                    charge_desc  injured  killed hit_run_lvl
# 25      TURNING MOVEMENTS AND REQUIRED SIGNALS        4       0         NaN
# 27        LEFT TURN YIELD UNTIL SAFE OR U-TURN        2       0         NaN
# 29  ENTERING HWY FROM PRIVATE ROAD OR DRIVEWAY        3       0         NaN

# %%
collisions[(collisions['injured'] > 1) & (collisions['injured'] < 4)].head(3)
# Out:
#    report_id            date_time  police_beat  street_no street_dir  \
# 27    170146  2017-01-01 19:45:00          822       5800
# 29    170122  2017-01-01 22:15:00          841       3400
# 38    170129  2017-01-02 14:10:00          722       1900
#
#    street_name street_type cross_st_dir cross_st_name cross_st_type  \
# 27    EL CAJON   BOULEVARD
# 29     COLLEGE      AVENUE
# 38        PALM      AVENUE
#
#    violation_section violation_type  \
# 27            21801A             VC
# 29             21804             VC
# 38             21703             VC
#
#                                    charge_desc  injured  killed hit_run_lvl
# 27        LEFT TURN YIELD UNTIL SAFE OR U-TURN        2       0         NaN
# 29  ENTERING HWY FROM PRIVATE ROAD OR DRIVEWAY        3       0         NaN
# 38                       FOLLOWING TOO CLOSELY        3       0         NaN

# %% [markdown]
# You can use brackets and column names to filter out information you don't want to look at at the moment. Filtering data is done by creating a boolean array, which is what 'collisions['injured'] > 1' creates, and then putting that in the brackets for collisions.
#
# A boolean array is a list of true and falses that matches the number of rows in the dataset, so true would mean keep the row, false would mean ignore it.

# %%
(collisions['injured'] > 1).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: injured, dtype: bool

# %% [markdown]
# ### Locating data: iloc vs loc

# %%
collisions.head(3)
# Out:
#   report_id            date_time  police_beat  street_no street_dir  \
# 0    170166  2017-01-01 00:01:00          124       8300
# 1    170101  2017-01-01 00:01:00          322       6400
# 2    170218  2017-01-01 00:01:00          325       8100
#
#    street_name street_type cross_st_dir cross_st_name cross_st_type  \
# 0  CAM DEL ORO
# 1     CRAWFORD      STREET
# 2  ROYAL GORGE       DRIVE
#
#   violation_section violation_type  \
# 0          MISC-HAZ             VC
# 1          MISC-HAZ             VC
# 2             22107             VC
#
#                                          charge_desc  injured  killed  \
# 0  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# 1  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# 2             TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
#
#    hit_run_lvl
# 0  MISDEMEANOR
# 1  MISDEMEANOR
# 2  MISDEMEANOR

# %%
collisions.iloc[1]
# Out:
# report_id                                                       170101
# date_time                                          2017-01-01 00:01:00
# police_beat                                                        322
# street_no                                                         6400
# street_dir
# street_name                                                   CRAWFORD
# street_type                                                     STREET
# cross_st_dir
# cross_st_name
# cross_st_type
# violation_section                                             MISC-HAZ
# violation_type                                                      VC
# charge_desc          MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...
# injured                                                              0
# killed                                                               0
# hit_run_lvl                                                MISDEMEANOR
# Name: 1, dtype: object

# %%
collisions.loc[1]
# Out:
# report_id                                                       170101
# date_time                                          2017-01-01 00:01:00
# police_beat                                                        322
# street_no                                                         6400
# street_dir
# street_name                                                   CRAWFORD
# street_type                                                     STREET
# cross_st_dir
# cross_st_name
# cross_st_type
# violation_section                                             MISC-HAZ
# violation_type                                                      VC
# charge_desc          MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...
# injured                                                              0
# killed                                                               0
# hit_run_lvl                                                MISDEMEANOR
# Name: 1, dtype: object

# %% [markdown]
# iloc will pull information at the given index, numerically. loc will do the same, except it can pull information when the index is named as well, so you can pass a string.
#
# You can also use iloc and loc to pull out multiple rows and columns.

# %%
collisions.iloc[1:3, 2:5]
# Out:
#    police_beat  street_no street_dir
# 1          322       6400
# 2          325       8100

# %%
collisions.loc[1:3, "police_beat":"street_dir"]
# Out:
#    police_beat  street_no street_dir
# 1          322       6400
# 2          325       8100
# 3          935       5500

# %% [markdown]
# You can also use slicing to pull out information.  The first parameter is the rows you want to include, and the second parameter are the columns you want to include.

# %%
collisions.drop('police_beat', axis=1).head(3)
# Out:
#   report_id            date_time  street_no street_dir  street_name  \
# 0    170166  2017-01-01 00:01:00       8300             CAM DEL ORO
# 1    170101  2017-01-01 00:01:00       6400                CRAWFORD
# 2    170218  2017-01-01 00:01:00       8100             ROYAL GORGE
#
#   street_type cross_st_dir cross_st_name cross_st_type violation_section  \
# 0                                                               MISC-HAZ
# 1      STREET                                                   MISC-HAZ
# 2       DRIVE                                                      22107
#
#   violation_type                                        charge_desc  injured  \
# 0             VC  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0
# 1             VC  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0
# 2             VC             TURNING MOVEMENTS AND REQUIRED SIGNALS        0
#
#    killed  hit_run_lvl
# 0       0  MISDEMEANOR
# 1       0  MISDEMEANOR
# 2       0  MISDEMEANOR

# %%
collisions['street_type'].unique()
# Out:
# array([' ', 'STREET', 'DRIVE', 'TRAIL', 'AVENUE', 'PLACE', 'COURT',
#        'ROAD', 'BOULEVARD', 'PARKWAY', 'WAY', 'COVE', 'CIRCLE', 'LANE',
#        'HIGHWAY', 'TERRACE', 'PLAZA', 'MALL', 'ROW', 'POINT', 'WALK',
#        'PASEO', 'SQUARE', 'RAMP', 'DRIVEWAY', 'KNOLLS', nan, 'LIGHTS'],
#       dtype=object)

# %%
collisions.groupby('street_type').mean().head()
# Out:
#              police_beat    street_no   injured    killed
# street_type
#               490.713604  5227.621321  0.640414  0.007955
# AVENUE        519.518253  3354.103436  0.595025  0.004474
# BOULEVARD     513.738517  4440.148282  0.732369  0.007233
# CIRCLE        578.274725  2264.835165  0.428571  0.000000
# COURT         415.598802  6344.311377  0.239521  0.000000

# %%
grouped = collisions.groupby('violation_type').sum()
grouped
# Out:
#                 police_beat  street_no  injured  killed
# violation_type
# CO                     2107      16000        5       0
# HS                      468       9900        1       0
# MC                     7103      26700       10       0
# PC                     1304      12300        1       0
# VC                 10758172   96644170    13580     114
# ZZ                     5504      68500        4       1

# %%
grouped.reset_index()
# Out:
#   violation_type  police_beat  street_no  injured  killed
# 0             CO         2107      16000        5       0
# 1             HS          468       9900        1       0
# 2             MC         7103      26700       10       0
# 3             PC         1304      12300        1       0
# 4             VC     10758172   96644170    13580     114
# 5             ZZ         5504      68500        4       1

# %%
def edit_row(row):
    if row['killed'] > 0:
        return 'fatal'
    return 'not fatal'

collisions['fatal'] = collisions.apply(edit_row, axis=1)
collisions.head()
# Out:
#   report_id            date_time  police_beat  street_no street_dir  \
# 0    170166  2017-01-01 00:01:00          124       8300
# 1    170101  2017-01-01 00:01:00          322       6400
# 2    170218  2017-01-01 00:01:00          325       8100
# 3    170082  2017-01-01 00:01:00          935       5500
# 4    170097  2017-01-01 01:00:00          521       1000
#
#    street_name street_type cross_st_dir cross_st_name cross_st_type  \
# 0  CAM DEL ORO
# 1     CRAWFORD      STREET
# 2  ROYAL GORGE       DRIVE
# 3      VALERIO       TRAIL
# 4         11TH      AVENUE
#
#   violation_section violation_type  \
# 0          MISC-HAZ             VC
# 1          MISC-HAZ             VC
# 2             22107             VC
# 3          MISC-HAZ             VC
# 4             22107             VC
#
#                                          charge_desc  injured  killed  \
# 0  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# 1  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# 2             TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
# 3  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# 4             TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
#
#    hit_run_lvl      fatal
# 0  MISDEMEANOR  not fatal
# 1  MISDEMEANOR  not fatal
# 2  MISDEMEANOR  not fatal
# 3  MISDEMEANOR  not fatal
# 4  MISDEMEANOR  not fatal

# %%
mini_row = collisions.head(1)
mini_row
# Out:
#   report_id            date_time  police_beat  street_no street_dir  \
# 0    170166  2017-01-01 00:01:00          124       8300
#
#    street_name street_type cross_st_dir cross_st_name cross_st_type  \
# 0  CAM DEL ORO
#
#   violation_section violation_type  \
# 0          MISC-HAZ             VC
#
#                                          charge_desc  injured  killed  \
# 0  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
#
#    hit_run_lvl      fatal
# 0  MISDEMEANOR  not fatal

# %%
# mini_row.apply(lambda x: print(x), axis=1)

# %%
# mini_row.apply(lambda x: print(x), axis=0)

# %%
collisions['new_time'] = collisions['date_time'].apply(pd.to_datetime)
collisions['new_time']
# Out:
# 0       2017-01-01 00:01:00
# 1       2017-01-01 00:01:00
# 2       2017-01-01 00:01:00
# 3       2017-01-01 00:01:00
# 4       2017-01-01 01:00:00
# 5       2017-01-01 01:00:00
# 6       2017-01-01 01:18:00
# 7       2017-01-01 01:53:00
# 8       2017-01-01 01:58:00
# 9       2017-01-01 02:00:00
# 10      2017-01-01 02:00:00
# 11      2017-01-01 02:03:00
# 12      2017-01-01 04:10:00
# 13      2017-01-01 04:43:00
# 14      2017-01-01 05:26:00
# 15      2017-01-01 06:56:00
# 16      2017-01-01 11:25:00
# 17      2017-01-01 11:37:00
# 18      2017-01-01 12:30:00
# 19      2017-01-01 13:00:00
# 20      2017-01-01 13:03:00
# 21      2017-01-01 13:16:00
# 22      2017-01-01 15:30:00
# 23      2017-01-01 15:30:00
# 24      2017-01-01 16:40:00
# 25      2017-01-01 18:07:00
# 26      2017-01-01 19:30:00
# 27      2017-01-01 19:45:00
# 28      2017-01-01 20:36:00
# 29      2017-01-01 22:15:00
#                 ...
# 22694   2019-04-11 21:08:00
# 22695   2019-04-12 07:59:00
# 22696   2019-04-12 10:27:00
# 22697   2019-04-12 10:57:00
# 22698   2019-04-12 11:35:00
# 22699   2019-04-12 14:00:00
# 22700   2019-04-12 14:09:50
# 22701   2019-04-12 18:10:17
# 22702   2019-04-12 18:25:00
# 22703   2019-04-12 19:00:00
# 22704   2019-04-13 01:20:00
# 22705   2019-04-13 12:33:00
# 22706   2019-04-13 13:30:41
# 22707   2019-04-13 14:11:00
# 22708   2019-04-13 15:28:23
# 22709   2019-04-13 15:35:00
# 22710   2019-04-13 19:02:00
# 22711   2019-04-14 00:17:41
# 22712   2019-04-14 01:20:00
# 22713   2019-04-14 02:15:00
# 22714   2019-04-14 10:51:00
# 22715   2019-04-14 10:53:18
# 22716   2019-04-14 12:30:00
# 22717   2019-04-14 16:08:00
# 22718   2019-04-14 18:03:00
# 22719   2019-04-14 19:41:00
# 22720   2019-04-15 08:00:00
# 22721   2019-04-15 09:30:00
# 22722   2019-04-15 10:04:08
# 22723   2019-04-15 20:45:00
# Name: new_time, Length: 22724, dtype: datetime64[ns]

# %%
grouped = collisions.groupby('injured').sum()
grouped.head()
# Out:
#          police_beat  street_no  killed
# injured
# 0            6052975   53616090      94
# 1            3674374   32125320      15
# 2             741354    7841250       3
# 3             212218    2234400       0
# 4              66336     679110       1

# %%
plt.plot(grouped.index, grouped.killed)
